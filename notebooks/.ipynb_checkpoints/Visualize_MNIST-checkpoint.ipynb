# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd 
from sklearn.datasets import fetch_mldata
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
#%matplotlib inline
import matplotlib 
#matplotlib.use('TKAgg')
# %matplotlib inline

# %%
import sys
sys.path.append('../adversarial/')
sys.path.append('../architectures/')

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
from torch import nn

# %%
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from torchvision import transforms, datasets
import torch

from net_mnist import Net, NetSoft, model_cnn

# %%
transform = transforms.ToTensor()
train = datasets.MNIST('../../data/MNIST', train=True, transform=transform, download=True)
val = datasets.MNIST('../../data/MNIST', train=False, transform=transform, download=True)

# %%
Xtens = torch.zeros([10000,1,28,28])
y = torch.zeros([10000])

for i in range(len(val)):
    Xtens[i,:,:,:],y[i] = val[i]

# %%
X = Xtens.view(-1,784)

# %% [markdown]
# ## PCA

# %%
pca = PCA(n_components=3)
pca_result = pca.fit_transform(X)
pc1 = pca_result[:,0]
pc2 = pca_result[:,1] 
pc3 = pca_result[:,2]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
#Explained variation per principal component: [0.09730166 0.07135901 0.06183721]
# Out:
# Explained variation per principal component: [0.10047663 0.07544487 0.06140516]

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.315s...
# [t-SNE] Computed neighbors for 10000 samples in 113.244s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 2.129212
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.916588
# [t-SNE] Error after 300 iterations: 2.783452
# t-SNE done! Time elapsed: 166.164968252182 seconds

# %%
ts1 = tsne_results[:,0]
ts2 = tsne_results[:,1]
plt.figure(figsize=(16,10))
leg= []
for i in range(10):    
    ind = torch.where(y==i)
    plt.scatter(ts1[ind], ts2[ind], marker='o')
    leg.append(str(i))
plt.legend(leg)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(10):    
    ind = torch.where(y==i)
    ax.scatter(xs=ts1[ind], ys=ts2[ind], zs=i)
                   
plt.legend(leg)

# %%
Net = model_cnn
NetName = 'model_cnn'

# %%
Net_AT = torch.load('../trainedmodels/MNIST/model_cnn_AT2_ep12_lr0.1.pt')
Net_AT = Net_AT.to('cuda')

# %%
Net_SGD = torch.load('../trainedmodels/MNIST/model_cnn_SGD_ep50_lr0.1.pt')

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
ypred1 = Net_SGD(Xtens.to('cuda'))
ypred2 = Net_AT(Xtens.to('cuda'))

# %%
y = y.long().to('cuda')

# %%
torch.sum(torch.argmax(ypred2,dim=1)==y)/10000.
# Out:
# tensor(0.9745, device='cuda:0')

# %%
torch.sum(torch.argmax(ypred1,dim=1)==y)/10000.
# Out:
# tensor(0.9877, device='cuda:0')

# %%
loss_p_sample1 = []
loss_p_sample2 = []
acc1 = []
acc2 = []
for i in range(10000):
    loss_p_sample1.append(loss_fn(torch.unsqueeze(ypred1[i],0),torch.unsqueeze(y[i],0)))
    acc1.append(torch.argmax(ypred1[i])==y[i])
    loss_p_sample2.append(loss_fn(torch.unsqueeze(ypred2[i],0),torch.unsqueeze(y[i],0)))
    acc2.append(torch.argmax(ypred2[i])==y[i])

# %%
loss_p_sample1 = torch.tensor(loss_p_sample1)
loss_p_sample2 = torch.tensor(loss_p_sample2)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
acc1 = torch.tensor(acc1)
acc2 = torch.tensor(acc2)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
for i in range(10):
    print('mnist digit',i,'\n')
    print('classifier 1 (sgd)\n')
    ind1 = y==i
    loss_p_sample1_1 = loss_p_sample1[ind1]
    print('accuracy of class %d : %2.4f'%(i,float(sum(acc1[ind1]==1))/float(len(acc1[ind1]))))
    print('minimum loss of misclassified digit with true index',i,':',loss_p_sample1_1[acc1[ind1]==0].min())
    print('maximum loss of correctly classified digit with true index',i,':',loss_p_sample1_1[acc1[ind1]==1].max(),'\n')
    print('classifier 2 (adv tr)\n')
    loss_p_sample2_1 = loss_p_sample2[ind1]
    print('accuracy of class %d : %2.4f'%(i,float(sum(acc2[ind1]==1))/float(len(acc2[ind1]))))
    print('minimum loss of misclassified digit with true index',i,':',loss_p_sample2_1[acc2[ind1]==0].min())
    print('maximum loss of correctly classified digit with true index',i,':',loss_p_sample2_1[acc2[ind1]==1].max(),'\n')
# Out:
# mnist digit 0
#
# classifier 1 (sgd)
#
# accuracy of class 0 : 0.9929
# minimum loss of misclassified digit with true index 0 : tensor(1.8459)
# maximum loss of correctly classified digit with true index 0 : tensor(0.3501)
#
# classifier 2 (adv tr)
#
# accuracy of class 0 : 0.9939
# minimum loss of misclassified digit with true index 0 : tensor(0.9376)
# maximum loss of correctly classified digit with true index 0 : tensor(0.5926)
#
# mnist digit 1
#
# classifier 1 (sgd)
#
# accuracy of class 1 : 0.9930
# minimum loss of misclassified digit with true index 1 : tensor(1.3150)
# maximum loss of correctly classified digit with true index 1 : tensor(0.6657)
#
# classifier 2 (adv tr)
#
# accuracy of class 1 : 0.9974
# minimum loss of misclassified digit with true index 1 : tensor(1.3075)
# maximum loss of correctly classified digit with true index 1 : tensor(0.7371)
#
# mnist digit 2
#
# classifier 1 (sgd)
#
# accuracy of class 2 : 0.9893
# minimum loss of misclassified digit with true index 2 : tensor(0.9170)
# maximum loss of correctly classified digit with true index 2 : tensor(0.6633)
#
# classifier 2 (adv tr)
#
# accuracy of class 2 : 0.9816
# minimum loss of misclassified digit with true index 2 : tensor(0.8071)
# maximum loss of correctly classified digit with true index 2 : tensor(0.8619)
#
# mnist digit 3
#
# classifier 1 (sgd)
#
# accuracy of class 3 : 0.9851
# minimum loss of misclassified digit with true index 3 : tensor(1.1071)
# maximum loss of correctly classified digit with true index 3 : tensor(0.6428)
#
# classifier 2 (adv tr)
#
# accuracy of class 3 : 0.9832
# minimum loss of misclassified digit with true index 3 : tensor(0.8042)
# maximum loss of correctly classified digit with true index 3 : tensor(1.3158)
#
# mnist digit 4
#
# classifier 1 (sgd)
#
# accuracy of class 4 : 0.9919
# minimum loss of misclassified digit with true index 4 : tensor(1.0816)
# maximum loss of correctly classified digit with true index 4 : tensor(0.8496)
#
# classifier 2 (adv tr)
#
# accuracy of class 4 : 0.9837
# minimum loss of misclassified digit with true index 4 : tensor(0.7448)
# maximum loss of correctly classified digit with true index 4 : tensor(0.9141)
#
# mnist digit 5
#
# classifier 1 (sgd)
#
# accuracy of class 5 : 0.9843
# minimum loss of misclassified digit with true index 5 : tensor(0.7348)
# maximum loss of correctly classified digit with true index 5 : tensor(0.6618)
#
# classifier 2 (adv tr)
#
# accuracy of class 5 : 0.9731
# minimum loss of misclassified digit with true index 5 : tensor(0.7312)
# maximum loss of correctly classified digit with true index 5 : tensor(0.9657)
#
# mnist digit 6
#
# classifier 1 (sgd)
#
# accuracy of class 6 : 0.9885
# minimum loss of misclassified digit with true index 6 : tensor(0.9956)
# maximum loss of correctly classified digit with true index 6 : tensor(0.6063)
#
# classifier 2 (adv tr)
#
# accuracy of class 6 : 0.9885
# minimum loss of misclassified digit with true index 6 : tensor(0.7882)
# maximum loss of correctly classified digit with true index 6 : tensor(0.8127)
#
# mnist digit 7
#
# classifier 1 (sgd)
#
# accuracy of class 7 : 0.9874
# minimum loss of misclassified digit with true index 7 : tensor(0.8357)
# maximum loss of correctly classified digit with true index 7 : tensor(0.5527)
#
# classifier 2 (adv tr)
#
# accuracy of class 7 : 0.9533
# minimum loss of misclassified digit with true index 7 : tensor(0.8225)
# maximum loss of correctly classified digit with true index 7 : tensor(1.0484)
#
# mnist digit 8
#
# classifier 1 (sgd)
#
# accuracy of class 8 : 0.9867
# minimum loss of misclassified digit with true index 8 : tensor(0.9017)
# maximum loss of correctly classified digit with true index 8 : tensor(0.5762)
#
# classifier 2 (adv tr)
#
# accuracy of class 8 : 0.9671
# minimum loss of misclassified digit with true index 8 : tensor(0.7801)
# maximum loss of correctly classified digit with true index 8 : tensor(1.0722)
#
# mnist digit 9
#
# classifier 1 (sgd)
#
# accuracy of class 9 : 0.9772
# minimum loss of misclassified digit with true index 9 : tensor(0.7445)
# maximum loss of correctly classified digit with true index 9 : tensor(0.6855)
#
# classifier 2 (adv tr)
#
# accuracy of class 9 : 0.9217
# minimum loss of misclassified digit with true index 9 : tensor(0.7100)
# maximum loss of correctly classified digit with true index 9 : tensor(1.1298)

# %%
ind1 = y==7
ind1= ind1.detach().cpu()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
loss_p_sample1_1 =  loss_p_sample1[ind1]
ts1_1 = ts1[ind1]
ts2_1 = ts2[ind1]
ax.scatter(xs=ts1_1[acc1[ind1]==1], ys=ts2_1[acc1[ind1]==1], zs=loss_p_sample1_1[acc1[ind1]==1])
ax.scatter(xs=ts1_1[acc1[ind1]==0], ys=ts2_1[acc1[ind1]==0], zs=loss_p_sample1_1[acc1[ind1]==0])
plt.legend(['correct','misclassify'])

# %%
ind2 = y==7
ind1= ind2.detach().cpu()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
loss_p_sample2_1 =  loss_p_sample2[ind1]
ts1_1 = ts1[ind1]
ts2_1 = ts2[ind1]
ax.scatter(xs=ts1_1[acc2[ind1]==1], ys=ts2_1[acc2[ind1]==1], zs=loss_p_sample2_1[acc2[ind1]==1])
ax.scatter(xs=ts1_1[acc2[ind1]==0], ys=ts2_1[acc2[ind1]==0], zs=loss_p_sample2_1[acc2[ind1]==0])
plt.legend(['correct','misclassify'])

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
X = ts1_1
Y = ts2_1
X, Y = np.meshgrid(X, Y)
v = loss_p_sample2[ind1].numpy()
for i in range(1028):
    Z[i,i] = v[i]
    
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(0, 5)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-283-8f36af942bc7> in <module>()
#       4 Z = loss_p_sample2[ind1]
#       5 surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
# ----> 6                        linewidth=0, antialiased=False)
#       7
#       8 # Customize the z axis.
#
# /home/gauri/.local/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1554
#    1555         if Z.ndim != 2:
# -> 1556             raise ValueError("Argument Z must be 2-dimensional.")
#    1557         if np.any(np.isnan(Z)):
#    1558             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.
